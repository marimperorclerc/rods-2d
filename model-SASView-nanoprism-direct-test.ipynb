# %%
from nanoprisms import *
import numpy as np

from matplotlib import pyplot as plt

# %%
sld=1
sld_solvent=0
nsides=5
Rave=600
L=3500
norder=20

# %%
from matplotlib import pyplot as plt

qs = np.logspace(-4,-1,400,base=10)


plt.plot(qs,[Iq(qi,sld,sld_solvent,nsides,Rave,L,norder)/volume(nsides,Rave,L)**2 for qi in qs])
plt.loglog()
plt.show()

# %%
Iq(0.01,sld,sld_solvent,nsides,Rave,L,norder)
# Out:
# 1.5208788429593384e+16

# %%
Iq([0.01],sld,sld_solvent,nsides,Rave,L,norder)
# Out:
# 1.5208788429593384e+16

# %%
Iq([0.01,0.02],sld,sld_solvent,nsides,Rave,L,norder)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Iq([0.01,0.02],sld,sld_solvent,nsides,Rave,L,norder)
#
# File d:\SAS-view-rods\nanoprisms-model-Sasview\nanoprisms.py:66, in Iq(q, sld, sld_solvent, nsides, Rave, L, norder)
#      64 order=int(orderlist[norder])
#      65 q_unit,w = leblib.get_points_and_weights(order)
# ---> 66 qa=q*q_unit[:,0]
#      67 qb=q*q_unit[:,1]
#      68 qc=q*q_unit[:,2]
#
# ValueError: operands could not be broadcast together with shapes (2,) (1454,)
